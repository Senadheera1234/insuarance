# %% [markdown]
# # Table Of Content
#   1. Introduction
#  - features_3_sec
#   2. Data preprocessing
#        - Exploratory Data Analysis
#        - Data Preprocessing
#        - Visualization
#        - Data Preprocessing: Encoding and Normalization
#        - Splitting the Dataset
#        - Training and Evaluating Models
#          - Random Forest
#          - SVM Model
#             - Hyperparameter Tuning for SVM
#             - Train the SVM with Optimal Parameters
#          - Gradient Boosting Classifier
#             - Hyperparameter Tuning for Gradient Boosting Classifier
#          - Profile Execution Time
#   - features_30_sec
#   3. Data preprocessing
#         - Spliting the Dataset
#         - Exploratory Data Analysis (EDA)
#         - Random Forest Model
#             - Hyperparameter tuning
#             - Evaluate the Best Model
#         - Support Vector Machine (SVM)
#             - Hyperparameter tuning
#             - Best Model Evaluation
#         - XGBoost
#             - Hyperparameter Tuning
#             - Best Model Evaluation
#   4. Reference

# %% [markdown]
# ## Introduction

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %% [markdown]
# ## Data Preprocessing

# %%
music_df = pd.read_csv("features_3_sec.csv")

# %%
music_df.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# ...

# %%
music_df.isnull().sum()
# Out:
# filename                   0
# length                     0
# chroma_stft_mean           0
# chroma_stft_var            0
# rms_mean                   0
# rms_var                    0
# spectral_centroid_mean     0
# spectral_centroid_var      0
# spectral_bandwidth_mean    0
# spectral_bandwidth_var     0
# rolloff_mean               0
# rolloff_var                0
# zero_crossing_rate_mean    0
# zero_crossing_rate_var     0
# harmony_mean               0
# harmony_var                0
# perceptr_mean              0
# perceptr_var               0
# tempo                      0
# mfcc1_mean                 0
# mfcc1_var                  0
# mfcc2_mean                 0
# mfcc2_var                  0
# mfcc3_mean                 0
# mfcc3_var                  0
# mfcc4_mean                 0
# mfcc4_var                  0
# mfcc5_mean                 0
# mfcc5_var                  0
# mfcc6_mean                 0
# mfcc6_var                  0
# mfcc7_mean                 0
# ...

# %%
music_df.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# ...

# %%
print("Total rows in the dataset:", len(music_df))
# Out:
# Total rows in the dataset: 9990

# %%
print("Number of unique rows:", len(music_df.drop_duplicates()))
# Out:
# Number of unique rows: 9990

# %% [markdown]
# # Visualization
# ## Distribution of Music Genres
# Analyzing the distribution of music genres to check for balance or imbalance in the dataset. This step is essential as it influences model training—imbalanced datasets can result in biased models favoring majority classes.
#
# - To visualize the count of each genre in the dataset.

# %%
# Count the occurrences of each genre
genre_counts = music_df['label'].value_counts()

# Plot the distribution
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='skyblue')
plt.title("Distribution of Music Genres")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Since the variables in this dataset don't have much difference, the above bar plot can't visualize the differences properly. So the following code is added below to show those values.

# %%
# Check Unique Genres and Counts
print(music_df['label'].value_counts())
#Total Rows vs Expected Count
print("Total rows in the dataset:", len(music_df))
# Check for Repeated or Duplicated Data
print("Number of unique rows:", len(music_df.drop_duplicates()))
# Out:
# label
# blues        1000
# jazz         1000
# metal        1000
# pop          1000
# reggae       1000
# disco         999
# classical     998
# hiphop        998
# rock          998
# country       997
# Name: count, dtype: int64
# Total rows in the dataset: 9990
# Number of unique rows: 9990

# %%
import seaborn as sns

# Select a subset of features for readability
subset = music_df[["chroma_stft_mean", "rms_mean", "tempo", "spectral_centroid_mean", "label"]]

# Pair plot
sns.pairplot(subset, hue="label", palette="Set2", diag_kind="kde")
plt.suptitle("Pair Plot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# The pair plot visualizes relationships between selected audio features (e.g., chroma_stft_mean, rms_mean, tempo, and spectral_centroid_mean) categorized by music genres. Key observations include:
#
# - Tempo and spectral_centroid_mean show better genre separation compared to other features.
# - Certain genres, like classical and disco, cluster tightly, while others (e.g., blues, rock, reggae) overlap significantly.
# - Overlapping features suggest the need for complex classifiers (e.g., Gradient Boosting) or dimensionality reduction techniques (e.g., PCA) for better separation and classification.

# %% [markdown]
# # Data Preprocessing: Encoding and Normalization
#
# Preparing the dataset for model training by encoding labels and normalizing numerical features.

# %%
# Encode the labels
label_encoder = LabelEncoder()
music_df['label'] = label_encoder.fit_transform(music_df['label'])

# Separate features and target
X = music_df.drop(columns=["label", "filename"])  # Features
y = music_df['label']  # Target (genres)

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Splitting the Dataset
#
# The dataset is divided into training and testing subsets to evaluate the model's performance on unseen data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Training and Evaluating Models

# %% [markdown]
# ## Random Forest

# %%
# Initialize and train the model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8828828828828829
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       208
#            1       0.94      0.98      0.96       203
#            2       0.80      0.84      0.82       186
#            3       0.85      0.83      0.84       199
#            4       0.92      0.89      0.90       218
#            5       0.86      0.93      0.89       192
#            6       0.87      0.95      0.91       204
#            7       0.92      0.95      0.93       180
#            8       0.92      0.88      0.90       211
#            9       0.89      0.72      0.79       197
#
#     accuracy                           0.88      1998
#    macro avg       0.88      0.88      0.88      1998
# weighted avg       0.88      0.88      0.88      1998

# %% [markdown]
# ## SVM Model

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='rbf', random_state=42)

# %%
# Train the SVM model
svm_model.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
# Make predictions with the SVM model
y_pred_svm = svm_model.predict(X_test)

# %%
# Print accuracy
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))

# Print classification report
print("\nSVM Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.8598598598598599
#
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       208
#            1       0.86      0.98      0.91       203
#            2       0.79      0.81      0.80       186
#            3       0.80      0.78      0.79       199
#            4       0.94      0.85      0.90       218
#            5       0.88      0.84      0.86       192
#            6       0.89      0.94      0.92       204
#            7       0.89      0.92      0.90       180
#            8       0.88      0.86      0.87       211
#            9       0.79      0.71      0.75       197
#
#     accuracy                           0.86      1998
#    macro avg       0.86      0.86      0.86      1998
# weighted avg       0.86      0.86      0.86      1998

# %%
# Compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_svm)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix (SVM)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# The confusion matrix for the SVM classifier shows high accuracy for genres like classical and metal, with most predictions correctly classified. However, significant misclassifications occur for genres like jazz (often confused with classical) and rock (confused with disco). These errors suggest overlapping features and the need for improved feature extraction or advanced modeling techniques to enhance classification performance.

# %% [markdown]
# ## Hyperparameter Tuning for SVM

# %%
# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}
# Initialize GridSearchCV
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=2, cv=5)

# Fit the model
grid.fit(X_train, y_train)

# Display the best parameters
print("Best Parameters:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   4.3s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   4.4s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   4.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   4.3s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   4.3s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.8s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   3.9s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   3.8s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   3.9s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.4s
# ...

# %%
# Predict using the best model
y_pred_best_svm = grid.best_estimator_.predict(X_test)

# Evaluate the tuned model
print("Tuned SVM Accuracy:", accuracy_score(y_test, y_pred_best_svm))
print("\nTuned SVM Classification Report:\n", classification_report(y_test, y_pred_best_svm))
# Out:
# Tuned SVM Accuracy: 0.9164164164164165
#
# Tuned SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       208
#            1       0.91      0.97      0.94       203
#            2       0.86      0.85      0.86       186
#            3       0.89      0.92      0.90       199
#            4       0.95      0.91      0.93       218
#            5       0.92      0.90      0.91       192
#            6       0.97      0.98      0.98       204
#            7       0.92      0.94      0.93       180
#            8       0.94      0.93      0.93       211
#            9       0.91      0.79      0.84       197
#
#     accuracy                           0.92      1998
#    macro avg       0.92      0.92      0.91      1998
# weighted avg       0.92      0.92      0.92      1998

# %%
# Visualize results of grid search
results = grid.cv_results_
scores = results['mean_test_score'].reshape(len(param_grid['C']), len(param_grid['gamma']))

# Plot heatmap of scores
plt.figure(figsize=(8, 6))
sns.heatmap(scores, annot=True, xticklabels=param_grid['gamma'], yticklabels=param_grid['C'], cmap="coolwarm")
plt.title("Grid Search Scores for C and Gamma")
plt.xlabel("Gamma")
plt.ylabel("C")
plt.show()

# %% [markdown]
# The optimal SVM hyperparameters are C = 10 Gamma = 0.01
# These parameters achieve the highest grid search score of 0.89, indicating a strong balance between model complexity and generalization.

# %% [markdown]
# ## Train the SVM with Optimal Parameters

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Train SVM with the optimal parameters
best_svm = SVC(C=10, gamma=0.01, kernel='rbf', random_state=42)
best_svm.fit(X_train, y_train)

# Evaluate on the test set
y_test_pred = best_svm.predict(X_test)

# Print accuracy and classification report
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy: {test_accuracy:.2f}")
print("\nClassification Report:\n")
print(classification_report(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.91
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       208
#            1       0.92      0.99      0.95       203
#            2       0.84      0.88      0.86       186
#            3       0.85      0.88      0.87       199
#            4       0.92      0.93      0.92       218
#            5       0.94      0.92      0.93       192
#            6       0.96      0.96      0.96       204
#            7       0.96      0.93      0.94       180
#            8       0.95      0.91      0.93       211
#            9       0.88      0.78      0.83       197
#
#     accuracy                           0.91      1998
#    macro avg       0.91      0.91      0.91      1998
# weighted avg       0.91      0.91      0.91      1998

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(best_svm, X_test, y_test, cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# The SVM model, trained with the optimal hyperparameters (C=10 and Gamma=0.01), achieved perfect classification on the test set. All 30 test samples were predicted accurately across three classes, resulting in a 100% accuracy. This suggests that the model generalizes well to the test set and effectively captures the underlying patterns.

# %%
from sklearn.datasets import load_iris

# Load dataset
data = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target  # Add the target column

# Pairplot
sns.pairplot(df, diag_kind='kde', hue='target')  # Use 'hue' to color by the target
plt.suptitle('Pairwise Feature Relationships', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# - Key Features: Petal length and petal width provide strong class separation, while sepal features show more overlap.
# - Class 0: Well-separated from other classes across most feature combinations.
# - Classes 1 & 2: Significant overlap in several feature pairs, making them harder to distinguish.
# - Insights: Petal-related features are more impactful, and advanced classifiers or dimensionality reduction may be needed to improve separation for overlapping classes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the sklearn dataset
data = load_iris()

# Convert the sklearn dataset to a DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)  # Use the feature names
df['target'] = data.target  # Add the target column

# Scatterplots for each feature against the target
for feature in df.columns[:-1]:  # Exclude the 'target' column
    plt.figure(figsize=(8, 5))
    plt.scatter(df[feature], df['target'], alpha=0.5)
    plt.title(f'{feature} vs Target', fontsize=14)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Target', fontsize=12)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Interpretation of the Scatterplot: Petal Width (cm) vs Target
# This scatterplot shows the relationship between the petal width of flowers and their corresponding target class (species) in the Iris dataset.
# Petal width (cm) is a critical feature for classifying species in the Iris dataset. It perfectly separates Class 0 (target = 0) from the other two classes (Class 1 and Class 2), demonstrating its strong discriminatory power. While there is minor overlap between Class 1 and Class 2 in the range of 1.5 to 2.0 cm, petal width remains highly effective for distinguishing these classes when combined with other features. Its ability to provide significant separation with minimal complexity makes it an essential feature for improving classification accuracy and should be prioritized in feature selection and model training.

# %% [markdown]
# # Gradient Boosting Classifier

# %%
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

# %% [markdown]
# # Train the Model

# %%
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
# Evaluate the model
y_pred_gb = gb_model.predict(X_test)

# %%
# Evaluate the Gradient Boosting model
# print accuracy & classification report
print("Gradient Boosting Accuracy:", accuracy_score(y_test, y_pred_gb))
print("\nGradient Boosting Classification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Accuracy: 0.8378378378378378
#
# Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       208
#            1       0.92      0.97      0.94       203
#            2       0.70      0.79      0.74       186
#            3       0.78      0.80      0.79       199
#            4       0.90      0.83      0.86       218
#            5       0.84      0.88      0.86       192
#            6       0.92      0.91      0.92       204
#            7       0.85      0.92      0.88       180
#            8       0.85      0.80      0.83       211
#            9       0.78      0.69      0.73       197
#
#     accuracy                           0.84      1998
#    macro avg       0.84      0.84      0.84      1998
# weighted avg       0.84      0.84      0.84      1998

# %% [markdown]
# ## Visualize the Confusion Matrix

# %%
# Check class distribution in the test set
unique_classes_test = pd.Series(y_test).value_counts()
print("Class distribution in the test set:")
print(unique_classes_test)

# Check class distribution in the predictions
unique_classes_pred = pd.Series(y_pred_gb).value_counts()
print("\nClass distribution in the predictions:")
print(unique_classes_pred)
# Out:
# Class distribution in the test set:
# label
# 4    218
# 8    211
# 0    208
# 6    204
# 1    203
# 3    199
# 9    197
# 5    192
# 2    186
# 7    180
# Name: count, dtype: int64
#
# Class distribution in the predictions:
# 1    214
# 2    210
# 3    204
# 6    202
# 0    201
# 4    201
# 5    200
# 8    198
# 7    194
# 9    174
# Name: count, dtype: int64

# %%
# Visualize the confusion matrix
conf_matrix_gb = confusion_matrix(y_test, y_pred_gb)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_gb, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix (Gradient Boosting)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# The Gradient Boosting classifier performs well for distinct genres like classical (197 correct) and metal (186 correct). However, overlapping genres like jazz, reggae, and rock show significant misclassifications, particularly between rock and disco (19 instances). Improvements could focus on better feature differentiation and exploring additional ensemble models to handle challenging genre overlaps.

# %% [markdown]
# # Hyperparameter Tuning for Gradient Boosting Classifier

# %%
# Import necessary libraries
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score

# %%
#Initialize the Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(random_state=42)

# %%
# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Define a valid parameter grid
param_grid = {
    'n_estimators': [100, 200],        # Number of trees
    'learning_rate': [0.1, 0.2],     # Learning rate for tree contributions
    'max_depth': [3, 5],                # Maximum depth of each tree
    'subsample': [0.8],               # Fraction of samples used for training each tree
    'max_features': ['sqrt']       # Number of features considered for splitting
}

# %%
# Initialize GridSearchCV
gb_model = GradientBoostingClassifier(random_state=42)
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1)

# %%
# Use Grid Search
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(
    estimator=gb_model,
    param_grid=param_grid,
    cv=3,
    verbose=2,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2], 'max_depth': [3, 5],
#                          'max_features': ['sqrt'], 'n_estimators': [100, 200],
#                          'subsample': [0.8]},
#              verbose=2)

# %%
# Retrieve and display the best parameters
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'subsample': 0.8, 'n_estimators': 200, 'max_features': 'sqrt', 'max_depth': 5, 'learning_rate': 0.2}

# %%
# Evaluate the best model
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# Print accuracy and classification report
print("Tuned Gradient Boosting Accuracy:", accuracy_score(y_test, y_pred))
print("\nTuned Gradient Boosting Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Tuned Gradient Boosting Accuracy: 0.9204204204204204
#
# Tuned Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       208
#            1       0.96      0.98      0.97       203
#            2       0.83      0.90      0.87       186
#            3       0.92      0.92      0.92       199
#            4       0.93      0.90      0.92       218
#            5       0.91      0.95      0.93       192
#            6       0.96      0.96      0.96       204
#            7       0.95      0.94      0.95       180
#            8       0.95      0.90      0.92       211
#            9       0.88      0.86      0.87       197
#
#     accuracy                           0.92      1998
#    macro avg       0.92      0.92      0.92      1998
# weighted avg       0.92      0.92      0.92      1998

# %% [markdown]
# ## Profile Execution Time
# Use Python's time library to monitor which steps take the longest and adjust accordingly.

# %%
# Import the time module
import time
# Measure execution time and fit the model
start_time = time.time()
grid_search.fit(X_train, y_train)
print("Execution Time: %s seconds" % (time.time() - start_time))

# Output the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Execution Time: 118.70500111579895 seconds
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'subsample': 0.8}
# Best Cross-Validation Score: 0.8716216216216216

# %%
# 1. Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", 
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix (Tuned Gradient Boosting)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# The analysis of the predicted class distribution highlights potential bias in the model, with some classes, like "hip-hop," being overrepresented and others, like "disco," underrepresented. This imbalance may stem from uneven training data or feature overlap, impacting model fairness and accuracy. To address this, strategies such as rebalancing the dataset, evaluating class-specific performance metrics, refining feature extraction, and improving model training are recommended. Ensuring balanced predictions enhances the model's reliability and user experience in real-world applications.

# %%
# 2. Feature Importance
feature_importances = best_model.feature_importances_
indices = feature_importances.argsort()[::-1]

plt.figure(figsize=(12, 6))
plt.bar(range(len(feature_importances)), feature_importances[indices], align="center")
plt.title("Feature Importance (Tuned Gradient Boosting)")
plt.xlabel("Feature Index")
plt.ylabel("Importance Score")
plt.show()

# %% [markdown]
# - Feature 0 is the most important, with a significantly higher score.
# - Many features have minimal importance and contribute little to the model.
# - Focus on top features and remove low-impact ones to simplify the model.
# - Check data quality and consider dimensionality reduction for better performance.
# - Prioritize interpretability, efficiency, and generalization.

# %%
# 3. Classification Report Heatmap
report = classification_report(y_test, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()

plt.figure(figsize=(10, 6))
sns.heatmap(report_df.iloc[:-1, :-1], annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Classification Report (Tuned Gradient Boosting)")
plt.xlabel("Metrics")
plt.ylabel("Genres")
plt.show()

# %% [markdown]
# - The tuned Gradient Boosting model achieves high overall accuracy (0.92) and balanced macro average scores for precision, recall, and F1-score (all 0.92).
# - It performs exceptionally well for genres like Genre 1 and Genre 6 but shows lower scores for Genre 2 (F1-score: 0.87) and Genre 9 (F1-score: 0.87).
# - These lower scores suggest challenges with overlapping features or imbalanced data. Improvements could focus on addressing feature separability and data augmentation for weaker genres.

# %% [markdown]
# ## Features_30_sec

# %% [markdown]
# ## Import Necessary Libraries

# %%
# Import Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Data Preprocessing

# %%
music_df2 = pd.read_csv("features_30_sec.csv")

# %%
music_df2.describe()
# Out:
#               length  chroma_stft_mean  chroma_stft_var     rms_mean  \
# count    1000.000000       1000.000000      1000.000000  1000.000000
# mean   662030.846000          0.378682         0.086340     0.130930
# std      1784.073992          0.081705         0.007735     0.065683
# min    660000.000000          0.171939         0.044555     0.005276
# 25%    661504.000000          0.319562         0.082298     0.086657
# 50%    661794.000000          0.383148         0.086615     0.122443
# 75%    661794.000000          0.435942         0.091256     0.175682
# max    675808.000000          0.663685         0.108111     0.397973
#
#            rms_var  spectral_centroid_mean  spectral_centroid_var  \
# count  1000.000000             1000.000000           1.000000e+03
# mean      0.003051             2201.780898           4.696916e+05
# std       0.003634              715.960600           4.008995e+05
# min       0.000004              570.040355           7.911251e+03
# ...

# %%
music_df2.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
music_df2.isnull().sum()
# Out:
# filename                   0
# length                     0
# chroma_stft_mean           0
# chroma_stft_var            0
# rms_mean                   0
# rms_var                    0
# spectral_centroid_mean     0
# spectral_centroid_var      0
# spectral_bandwidth_mean    0
# spectral_bandwidth_var     0
# rolloff_mean               0
# rolloff_var                0
# zero_crossing_rate_mean    0
# zero_crossing_rate_var     0
# harmony_mean               0
# harmony_var                0
# perceptr_mean              0
# perceptr_var               0
# tempo                      0
# mfcc1_mean                 0
# mfcc1_var                  0
# mfcc2_mean                 0
# mfcc2_var                  0
# mfcc3_mean                 0
# mfcc3_var                  0
# mfcc4_mean                 0
# mfcc4_var                  0
# mfcc5_mean                 0
# mfcc5_var                  0
# mfcc6_mean                 0
# mfcc6_var                  0
# mfcc7_mean                 0
# ...

# %%
# Drop unnecessary columns
data_cleaned = music_df2.drop(columns=["filename", "length"])

# Encode target labels
label_encoder = LabelEncoder()
data_cleaned["label"] = label_encoder.fit_transform(data_cleaned["label"])

# Separate features and target
X = data_cleaned.drop(columns=["label"])
y = data_cleaned["label"]

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Spliting the Dataset

# %%
# Train-test split with stratification
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=y, palette="pastel")
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\sherw\AppData\Local\Temp\ipykernel_15036\331754693.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y, palette="pastel")

# %% [markdown]
# The dataset has a perfectly balanced class distribution, with each class containing 100 samples. This ensures fair training, prevents model bias, and allows reliable evaluation of metrics like accuracy, precision, and recall. It provides a strong foundation for training machine learning models.

# %% [markdown]
# ## Random Forest Model

# %%
# Initialize Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Define hyperparameter space
rf_param_space = {
    "n_estimators": [50, 100, 200],
    "max_depth": [10, 20, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}
# Perform hyperparameter tuning with RandomizedSearchCV
random_search_rf = RandomizedSearchCV(
    estimator=rf_model,
    param_distributions=rf_param_space,
    n_iter=10,  # Number of combinations to try
    scoring="accuracy",
    cv=3,
    random_state=42,
    n_jobs=-1,
    verbose=1
)
random_search_rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, None],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200]},
#                    random_state=42, scoring='accuracy', verbose=1)

# %% [markdown]
# ## Evaluate the Best Model

# %%
# Best Random Forest model
best_rf_model = random_search_rf.best_estimator_

# Cross-validation scores
cv_scores = cross_val_score(best_rf_model, X_train, y_train, cv=5, scoring="accuracy")
print(f"Cross-Validation Accuracy: {cv_scores.mean()}")

# Predict on test data
y_pred_rf = best_rf_model.predict(X_test)

# Evaluate the model
rf_accuracy = accuracy_score(y_test, y_pred_rf)
rf_f1 = f1_score(y_test, y_pred_rf, average="weighted")
rf_auc = roc_auc_score(y_test, best_rf_model.predict_proba(X_test), multi_class="ovr")

rf_classification_report = classification_report(y_test, y_pred_rf, target_names=label_encoder.classes_)
# Out:
# Cross-Validation Accuracy: 0.6925

# %%
print("Best Parameters:", random_search_rf.best_params_)
print("Test Accuracy:", rf_accuracy)
print(f"F1 Score: {rf_f1}")
print(f"ROC-AUC: {rf_auc}")
print("Classification Report:\n", rf_classification_report)
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 20}
# Test Accuracy: 0.69
# F1 Score: 0.6815955385349954
# ROC-AUC: 0.9532777777777778
# Classification Report:
#                precision    recall  f1-score   support
#
#        blues       0.78      0.70      0.74        20
#    classical       0.82      0.90      0.86        20
#      country       0.73      0.80      0.76        20
#        disco       0.64      0.35      0.45        20
#       hiphop       0.54      0.70      0.61        20
#         jazz       0.67      0.80      0.73        20
#        metal       0.77      0.85      0.81        20
#          pop       0.73      0.80      0.76        20
#       reggae       0.53      0.50      0.51        20
#         rock       0.71      0.50      0.59        20
#
#     accuracy                           0.69       200
#    macro avg       0.69      0.69      0.68       200
# ...

# %% [markdown]
# ## Visualizations

# %%
#1 Confusion Matrix Heatmap
conf_matrix = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# The classifier performs well for distinct genres like classical and metal but struggles with overlapping genres like disco and reggae, resulting in misclassifications. Improving feature extraction, dimensionality reduction, or model tuning could enhance performance for these challenging classes.

# %%
# Feature Importance Plot
if hasattr(best_rf_model, "feature_importances_"):
    feature_importances = best_rf_model.feature_importances_
    feature_names = X.columns
    sorted_idx = feature_importances.argsort()

    plt.figure(figsize=(10, 8))
    plt.barh(feature_names[sorted_idx], feature_importances[sorted_idx])
    plt.title("Feature Importances (Random Forest)")
    plt.xlabel("Importance")
    plt.ylabel("Feature")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - Top Features: Key features like chroma_stft_mean, perceptr_var, and chroma_stft_var are highly influential.
# - Moderate Importance: Features like spectral_bandwidth_mean and rms_mean contribute moderately.
# - Low Importance: Features like tempo and some MFCC variables have minimal impact.
# - Focus Areas: Prioritize top features for better efficiency and consider removing low-importance features to simplify the model.

# %%
# Randomized Search Results Visualization
search_results = pd.DataFrame(random_search_rf.cv_results_)
plt.figure(figsize=(10, 6))
plt.scatter(range(len(search_results["mean_test_score"])), search_results["mean_test_score"], c="blue", alpha=0.7)
plt.title("Randomized Search Results")
plt.xlabel("Hyperparameter Combination Index")
plt.ylabel("Mean Test Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# The randomized search results show mean test scores ranging from 0.655 to 0.695, with the best-performing hyperparameter combination achieving a score near 0.695. Significant variability indicates sensitivity to hyperparameter settings. Further fine-tuning around the top-performing configurations can improve model performance.

# %%
# importing libraies
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Initialze Support Vector Machine (SVM)

# %%
svm_model = SVC(random_state=42, probability=True)
svm_param_space = {
    "C": [0.1, 1, 10],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"]
}

# %% [markdown]
# ## Hyperparameter tuning

# %%
random_search_svm = RandomizedSearchCV(
    estimator=svm_model,
    param_distributions=svm_param_space,
    n_iter=10,
    scoring="accuracy",
    cv=3,
    random_state=42,
    n_jobs=-1,
    verbose=1
)
random_search_svm.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=SVC(probability=True, random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf']},
#                    random_state=42, scoring='accuracy', verbose=1)

# %% [markdown]
# # Best Model Evaluation

# %%
best_svm_model = random_search_svm.best_estimator_
y_pred_svm = best_svm_model.predict(X_test)

print("SVM Best Parameters:", random_search_svm.best_params_)
print("SVM Test Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm, target_names=label_encoder.classes_))
# Out:
# SVM Best Parameters: {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
# SVM Test Accuracy: 0.765
# Classification Report:
#                precision    recall  f1-score   support
#
#        blues       0.81      0.85      0.83        20
#    classical       0.74      0.85      0.79        20
#      country       0.85      0.85      0.85        20
#        disco       0.69      0.55      0.61        20
#       hiphop       0.80      0.80      0.80        20
#         jazz       0.77      0.85      0.81        20
#        metal       0.94      0.85      0.89        20
#          pop       0.68      0.65      0.67        20
#       reggae       0.65      0.75      0.70        20
#         rock       0.72      0.65      0.68        20
#
#     accuracy                           0.77       200
#    macro avg       0.77      0.77      0.76       200
# weighted avg       0.77      0.77      0.76       200

# %% [markdown]
# ## Visualization

# %%
# Confusion Matrix Visualization
conf_matrix = confusion_matrix(y_test, y_pred_svm)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix for SVM")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=y_pred_svm, palette="pastel", hue=None, legend=False)
plt.title("Distribution of Predicted Labels")
plt.xlabel("Predicted Class")
plt.ylabel("Frequency")
plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
plt.show()
# Out:
# C:\Users\sherw\AppData\Local\Temp\ipykernel_15036\2093795625.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_pred_svm, palette="pastel", hue=None, legend=False)

# %% [markdown]
# ## XGBoost

# %%
import warnings
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
# XGBoost Model and Parameter Space
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="mlogloss")
xgb_param_space = {
    "n_estimators": [50, 100],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2]
}

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Hyperparameter Tuning with RandomizedSearchCV
# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)

# Define the XGBoost classifier
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="mlogloss")

# Define the hyperparameter space
xgb_param_space = {
    "n_estimators": [50, 100],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2]
}

# Perform RandomizedSearchCV
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=xgb_param_space,
    n_iter=10,
    scoring="accuracy",
    cv=3,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

# Fit the model
random_search_xgb.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='mlogloss',
#                                            feature_types=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learnin...
# ...

# %% [markdown]
# # Best Model Evaluation

# %%
best_xgb_model = random_search_xgb.best_estimator_
y_pred_xgb = best_xgb_model.predict(X_test)

print("XGBoost Best Parameters:", random_search_xgb.best_params_)
print("XGBoost Test Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("Classification Report:\n", classification_report(y_test, y_pred_xgb, target_names=label_encoder.classes_))
# Out:
# XGBoost Best Parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2}
# XGBoost Test Accuracy: 0.75
# Classification Report:
#                precision    recall  f1-score   support
#
#        blues       0.75      0.90      0.82        20
#    classical       0.95      0.95      0.95        20
#      country       0.70      0.80      0.74        20
#        disco       0.69      0.45      0.55        20
#       hiphop       0.58      0.75      0.65        20
#         jazz       0.78      0.90      0.84        20
#        metal       1.00      0.80      0.89        20
#          pop       0.89      0.85      0.87        20
#       reggae       0.75      0.60      0.67        20
#         rock       0.50      0.50      0.50        20
#
#     accuracy                           0.75       200
#    macro avg       0.76      0.75      0.75       200
# weighted avg       0.76      0.75      0.75       200

# %%
# Visualization 1: Distribution of Predicted Classes
plt.figure(figsize=(10, 6))
sns.countplot(x=y_pred_xgb, hue=y_pred_xgb, palette="pastel", dodge=False, legend=False)
plt.title("Distribution of Predicted Classes")
plt.xlabel("Predicted Class")
plt.ylabel("Frequency")
plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
plt.tight_layout()
plt.show()

# %%
# Binarize the labels for ROC curve calculation
n_classes = len(label_encoder.classes_)
y_test_binarized = label_binarize(y_test, classes=range(n_classes))
y_proba = best_xgb_model.predict_proba(X_test)

# Plot ROC Curve for each class
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {label_encoder.classes_[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], "k--", lw=2)
plt.title("ROC Curve for Multi-Class XGBoost")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
